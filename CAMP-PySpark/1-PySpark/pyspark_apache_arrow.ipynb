# %% [markdown]
# # PySpark: Apache Arrow in PySpark
#
# Apache Arrow is an in-memory columnar data format that is used in Spark to efficiently transfer data between JVM and Python processes. This currently is most beneficial to Python users that work with Pandas/NumPy data. Its usage is not automatic and might require some minor changes to configuration or code to take full advantage and ensure compatibility. This guide will give a high-level description of how to use Arrow in Spark and highlight any differences when working with Arrow-enabled data.

# %% [markdown]
# ## Ensure PyArrow Installed
#
# > pip install pyspark[sql]

# %% [markdown]
# ## Importing libraries

# %%
import numpy as np
import pandas as pd

from typing import Iterator, Tuple
from collections.abc import Iterable

from pyspark.sql import SparkSession, Window
from pyspark.sql.functions import pandas_udf, col, udf
from pyspark.sql.types import LongType

# %% [markdown]
# ## Connect to Spark

# %%
spark = SparkSession.builder.getOrCreate()

# %%
# Enable spark.sql.repl.eagerEval.enabled configuration for the eager evaluation of PySpark DataFrame in notebooks
spark.conf.set('spark.sql.repl.eagerEval.enabled', True)

# %% [markdown]
# ## Enabling for Conversion to/from Pandas

# %%
# Enable Arrow-based columnar data transfers
spark.conf.set("spark.sql.execution.arrow.pyspark.enabled", "true")

# Generate a Pandas DataFrame
pdf = pd.DataFrame(np.random.rand(100, 3))

# Create a Spark DataFrame from a Pandas DataFrame using Arrow
df = spark.createDataFrame(pdf)

print((df.count(), len(df.columns)))
df
# Out:
# (100, 3)
# +-------------------+--------------------+--------------------+
# |                  0|                   1|                   2|
# +-------------------+--------------------+--------------------+
# | 0.7291865844577463| 0.05769977034892937|  0.6119386821579402|
# |0.09548388110080708|0.025158153501688263| 0.22543414053019972|
# | 0.2813354334150675|   0.910623166825474|  0.5944292067125433|
# | 0.5067731748746892|  0.5757785296098157|  0.3763023430576873|
# | 0.5982811524192732|  0.7591795215663704| 0.42789773135453923|
# | 0.5618393950837094|  0.5725260975434148|  0.7281249580173462|
# | 0.8316584326501649| 0.18955216034439892|  0.8625650733131315|
# |  0.663544579446418| 0.09534626904068322|  0.7165214707141393|
# |  0.517680381448572|   0.862566859854438|  0.8656171889663078|
# |0.35906442648407255|  0.1284729310489291| 0.46599208985297846|
# |  0.261954929633467|  0.5886487158682753|  0.7070726791269435|
# | 0.8686975906607558|  0.5637707915334207|   0.987455670611681|
# | 0.6952514014906328| 0.08723608673945582|  0.9353599905295831|
# |0.38041473114885516|  0.5953561656055524|  0.8188067372508769|
# |0.22092395291099065|   0.492606802269449|  0.4719219256438222|
# |  0.489434394468648|  0.2998093291573126|0.012536650152832451|
# |0.15192613269283506|  0.7555785394115917| 0.07446602127627533|
# |0.15079379922932168|   0.745728145471321| 0.47694057196144646|
# |0.13786190528238418| 0.19406037385708763|  0.8618833794909825|
# | 0.6869376813195135| 0.41503907982973975|  0.9987822222739546|
# +-------------------+--------------------+--------------------+
# only showing top 20 rows

# %%
# Convert the Spark DataFrame back to a Pandas DataFrame using Arrow
result_pdf = df.select("*").toPandas()

print("Pandas DataFrame result statistics:\n%s\n" % str(result_pdf.describe()))
# Out:
# Pandas DataFrame result statistics:
#                 0           1           2
# count  100.000000  100.000000  100.000000
# mean     0.504956    0.548975    0.526956
# std      0.270748    0.294841    0.299672
# min      0.000234    0.019201    0.003909
# 25%      0.256258    0.299184    0.264691
# 50%      0.551159    0.582503    0.534926
# 75%      0.702453    0.782146    0.782160
# max      0.970770    0.989971    0.998782

# %% [markdown]
# ## Pandas UDFs (a.k.a. Vectorized UDFs)

# %% [markdown]
# ### Series to Series

# %%
# Declare the function and create the UDF
def multiply_func(a: pd.Series, b: pd.Series) -> pd.Series:
    return a * b

multiply = pandas_udf(multiply_func, returnType=LongType())  # type: ignore[call-overload]

# The function for a pandas_udf should be able to execute with local Pandas data
x = pd.Series([1, 2, 3])
print(multiply_func(x, x))
# Out:
# 0    1
# 1    4
# 2    9
# dtype: int64

# %%
# Create a Spark DataFrame, 'spark' is an existing SparkSession
df = spark.createDataFrame(pd.DataFrame(x, columns=["x"]))

# Execute function as a Spark vectorized UDF
df.select(multiply(col("x"), col("x"))).show()
# Out:
# +-------------------+
# |multiply_func(x, x)|
# +-------------------+
# |                  1|
# |                  4|
# |                  9|
# +-------------------+

# %% [markdown]
# ### Iterator of Series to Iterator of Series

# %%
pdf = pd.DataFrame([1, 2, 3], columns=["x"])
df = spark.createDataFrame(pdf)
df.show()
# Out:
# +---+
# |  x|
# +---+
# |  1|
# |  2|
# |  3|
# +---+

# %%
# Declare the function and create the UDF
@pandas_udf("long")  # type: ignore[call-overload]
def plus_one(iterator: Iterator[pd.Series]) -> Iterator[pd.Series]:
    for x in iterator:
        yield x + 1

df.select(plus_one("x")).show()
# Out:
# +-----------+
# |plus_one(x)|
# +-----------+
# |          2|
# |          3|
# |          4|
# +-----------+

# %% [markdown]
# ### Iterator of Multiple Series to Iterator of Series

# %%
pdf = pd.DataFrame([(1, 1), (2, 4), (3, 9)], columns=["x", "y"])
df = spark.createDataFrame(pdf)
df
# Out:
# +---+---+
# |  x|  y|
# +---+---+
# |  1|  1|
# |  2|  4|
# |  3|  9|
# +---+---+

# %%
# Declare the function and create the UDF
@pandas_udf("long")  # type: ignore[call-overload]
def multiply_two_cols(
        iterator: Iterator[Tuple[pd.Series, pd.Series]]) -> Iterator[pd.Series]:
    for a, b in iterator:
        yield a * b

df.select(multiply_two_cols("x", "y")).show()
# Out:
# +-----------------------+
# |multiply_two_cols(x, y)|
# +-----------------------+
# |                      1|
# |                      8|
# |                     27|
# +-----------------------+

# %% [markdown]
# ### Series to Scalar

# %%
df = spark.createDataFrame(
    [(1, 1.0), (1, 2.0), (2, 3.0), (2, 5.0), (2, 10.0)],
    ("id", "v")
)
df
# Out:
# +---+----+
# | id|   v|
# +---+----+
# |  1| 1.0|
# |  1| 2.0|
# |  2| 3.0|
# |  2| 5.0|
# |  2|10.0|
# +---+----+

# %%
# Declare the function and create the UDF
@pandas_udf("double")  # type: ignore[call-overload]
def mean_udf(v: pd.Series) -> float:
    return v.mean()

df.select(mean_udf(df['v'])).show()
# Out:
# +-----------+
# |mean_udf(v)|
# +-----------+
# |        4.2|
# +-----------+

# %%
df.groupby("id").agg(mean_udf(df['v'])).show()
# Out:
# +---+-----------+
# | id|mean_udf(v)|
# +---+-----------+
# |  1|        1.5|
# |  2|        6.0|
# +---+-----------+

# %%
w = (Window.partitionBy('id')
           .rowsBetween(Window.unboundedPreceding, Window.unboundedFollowing))
df.withColumn('mean_v', mean_udf(df['v']).over(w)).show()
# Out:
# +---+----+------+
# | id|   v|mean_v|
# +---+----+------+
# |  1| 1.0|   1.5|
# |  1| 2.0|   1.5|
# |  2| 3.0|   6.0|
# |  2| 5.0|   6.0|
# |  2|10.0|   6.0|
# +---+----+------+

# %%
df.groupby("id").avg()
# Out:
# +---+-------+------+
# | id|avg(id)|avg(v)|
# +---+-------+------+
# |  1|    1.0|   1.5|
# |  2|    2.0|   6.0|
# +---+-------+------+

# %% [markdown]
# ## Pandas Function APIs

# %% [markdown]
# ### Grouped Map

# %%
df = spark.createDataFrame(
    [(1, 1.0), (1, 2.0), (2, 3.0), (2, 5.0), (2, 10.0)],
    ("id", "v"))
df.show()

df.groupby("id").agg(mean_udf(df['v'])).show()
# Out:
# +---+----+
# | id|   v|
# +---+----+
# |  1| 1.0|
# |  1| 2.0|
# |  2| 3.0|
# |  2| 5.0|
# |  2|10.0|
# +---+----+
#
# +---+-----------+
# | id|mean_udf(v)|
# +---+-----------+
# |  1|        1.5|
# |  2|        6.0|
# +---+-----------+

# %%
def subtract_mean(pdf: pd.DataFrame) -> pd.DataFrame:
    # pdf is a pandas.DataFrame
    v = pdf.v
    return pdf.assign(v=v - v.mean())

df.groupby("id").applyInPandas(subtract_mean, schema="id long, v double").show()
# Out:
# +---+----+
# | id|   v|
# +---+----+
# |  1|-0.5|
# |  1| 0.5|
# |  2|-3.0|
# |  2|-1.0|
# |  2| 4.0|
# +---+----+

# %% [markdown]
# ### Map

# %%
df = spark.createDataFrame([(1, 21), (2, 30)], ("id", "age"))
df.show()
# Out:
# +---+---+
# | id|age|
# +---+---+
# |  1| 21|
# |  2| 30|
# +---+---+

# %%
def filter_func(iterator: Iterable[pd.DataFrame]) -> Iterable[pd.DataFrame]:
    for pdf in iterator:
        yield pdf[pdf.id == 1]

df.mapInPandas(filter_func, schema=df.schema).show()
# Out:
# +---+---+
# | id|age|
# +---+---+
# |  1| 21|
# +---+---+

# %% [markdown]
# ### Co-grouped Map

# %%
df1 = spark.createDataFrame(
    [(20000101, 1, 1.0), (20000101, 2, 2.0), (20000102, 1, 3.0), (20000102, 2, 4.0)],
    ("time", "id", "v1"))

df2 = spark.createDataFrame(
    [(20000101, 1, "x"), (20000101, 2, "y")],
    ("time", "id", "v2"))

df1.show()
df2.show()
# Out:
# +--------+---+---+
# |    time| id| v1|
# +--------+---+---+
# |20000101|  1|1.0|
# |20000101|  2|2.0|
# |20000102|  1|3.0|
# |20000102|  2|4.0|
# +--------+---+---+
#
# +--------+---+---+
# |    time| id| v2|
# +--------+---+---+
# |20000101|  1|  x|
# |20000101|  2|  y|
# +--------+---+---+

# %%
def merge_ordered(left: pd.DataFrame, right: pd.DataFrame) -> pd.DataFrame:
    return pd.merge_ordered(left, right)

(df1.groupby("id")
    .cogroup(df2.groupby("id"))
    .applyInPandas(merge_ordered, schema="time int, id int, v1 double, v2 string")).show()
# Out:
# +--------+---+---+----+
# |    time| id| v1|  v2|
# +--------+---+---+----+
# |20000101|  1|1.0|   x|
# |20000102|  1|3.0|NULL|
# |20000101|  2|2.0|   y|
# |20000102|  2|4.0|NULL|
# +--------+---+---+----+

# %% [markdown]
# ## Arrow Python UDFs
#
# Arrow Python UDFs are user defined functions that are executed row-by-row, utilizing Arrow for efficient batch data transfer and serialization. To define an Arrow Python UDF, you can use the udf() decorator or wrap the function with the udf() method, ensuring the useArrow parameter is set to True. Additionally, you can enable Arrow optimization for Python UDFs throughout the entire SparkSession by setting the Spark configuration spark.sql

# %%
df = spark.createDataFrame([(1, "John Doe", 21)], ("id", "name", "age"))
df.show()
# Out:
# +---+--------+---+
# | id|    name|age|
# +---+--------+---+
# |  1|John Doe| 21|
# +---+--------+---+

# %%
@udf(returnType='int')  # A default, pickled Python UDF
def slen(s):  # type: ignore[no-untyped-def]
    return len(s)

@udf(returnType='int', useArrow=True)  # An Arrow Python UDF
def arrow_slen(s):  # type: ignore[no-untyped-def]
    return len(s)

df.select(slen("name"), arrow_slen("name")).show()
# Out:
# +----------+----------------+
# |slen(name)|arrow_slen(name)|
# +----------+----------------+
# |         8|               8|
# +----------+----------------+

# %% [markdown]
# ## Close session

# %%
spark.stop()

# %% [markdown]
# ----------------------------
